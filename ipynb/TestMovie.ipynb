# %%
from ecell4.core import *
from ecell4.util import *
from ecell4 import lattice, egfrd
viz.init_ipynb()
# Out:
# <script>
# if(window['d3'] === undefined ||
#    window['THREE'] === undefined ||
#    window['Elegans'] === undefined){
#     var paths = {
# 	d3: 'http://cdnjs.cloudflare.com/ajax/libs/d3/3.4.4/d3.min',
# 	THREE: 'http://cdnjs.cloudflare.com/ajax/libs/three.js/r66/three.min'
#     };
#
#     var shim = {
# 	'THREE': {exports: 'THREE'}
#     };
#
#     console.log('Begin loading all JavaScript libs...');
#     require.config({paths: paths, shim: shim});
#
#     require(['d3', 'THREE'], function(d3, THREE){
# 	window['d3'] = d3;
# 	window['THREE'] = THREE;
# 	console.log('Finished loading d3.js and Three.js.');
#
# 	// URL shown below (rawgit.com) should be replaced!
# 	var script = d3.select("head")
# 	    .append("script")
# 	    // .attr("src", 'https://rawgit.com/domitry/elegans/master/release/elegans.js')
# 	    .attr("src", 'https://rawgit.com/domitry/elegans/microbial-sim/release/elegans.js')
# 	    .attr("async", true);
#
# 	script[0][0].onload = script[0][0].onreadystatechange = function(){
# 	    var event = document.createEvent("HTMLEvents");
# 	    event.initEvent("load_elegans", true, false);
# 	    window.dispatchEvent(event);
# 	    console.log('Finished loading Elegans.js ;)');
# 	};
#     });
# }
# </script>

# %%
with species_attributes():
    A | B | C | {"D": "1", "radius": "0.005"}

with reaction_rules():
    A + B <> C | (0.05, 0.3)

m = get_model(False)

# %%
# factory = egfrd.EGFRDFactory(Global(4, 4, 4))
factory = lattice.LatticeFactory(0.005)

# %%
w = factory.create_world(Position3(1, 1, 1))
w.bind_to(m)
w.add_molecules(Species("A"), 60, AABB(Position3(0, 0, 0), Position3(0.5, 1, 1)))
w.add_molecules(Species("B"), 60, AABB(Position3(0.5, 0, 0), Position3(1, 1, 1)))

# %%
sim = factory.create_simulator(w)
obs1 = FixedIntervalHDF5Observer(0.02, "test%03d.h5")
obs2 = NumberObserver(("A", "C"))
sim.run(1.0, [obs1, obs2])

# %%
viz.plot_movie([factory.create_world("test%03d.h5" % _) for _ in xrange(51)], radius=0.005, grid=False, species_list=("A", "B", "C"))
# Out:
# <html>
#   <head>
#     <script type="text/javascript">
#      //
#      // templ variables: model_id, data
#      // * model_id: uuid
#      // * data: array of array of hash
#      //    [
#      //      [{df: {x: [0,1,2,..,4], y: [], z: []}, t: 0}, {}],
#      //      [],[],[],...
#      //    ]
#      // * colors: array of string
#      // * names: array of string
#      // * options: hash
#      //
#      (function(){
#        function render(){
# 	 console.log("Begin rendering...");
# 	 var stage = new Elegans.Stage(d3.select("#"+"movie7d839fbc-8955-43f3-b511-706e5a08fb6e")[0][0], {"player": true, "range": {"y": [0.0, 1.0], "x": [0.0, 1.0], "z": [0.0, 1.0]}, "grid": false, "autorange": false, "space_mode": "wireframe"});
# 	 var data = [[{"df": {"y": [0.21650635094610965, 0.8400446416709055, 0.23671361036774657, 0.2540341184434353, 0.4358994532381674, 0.89489291724392, 0.268467875173176, 0.3406366588218792, 0.046188021535170064, 0.649519052838329, 0.35507041555161983, 0.8054036255195279, 0.8342711389790093, 0.4763139720814413, 0.8054036255195279, 0.3233161507461904, 0.762102355330306, 0.6697263122599659, 0.2800148805569685, 0.2944486372867091, 0.3233161507461904, 0.36661742093541233, 0.3233161507461904, 0.6754998149518622, 0.7043673284113435, 0.3637306695894642, 0.6697263122599659, 0.9555146955088307, 0.8833459118601275, 0.7130275824491878, 0.3233161507461904, 0.8487048957087499, 0.3117691453623979, 0.8833459118601275, 0.7880831174438392, 0.7014805770653953, 0.06928203230275509, 0.6004442799572108, 0.8082903768654761, 0.3204293994002423, 