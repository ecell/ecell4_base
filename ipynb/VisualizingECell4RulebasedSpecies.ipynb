# %%
from ecell4.util import cyjs

# %%
from ecell4.core import *

# %%
egf = Species("EGF(R)")

# %%
egfr = Species("EGFR(L,CR1,Y1068=P)")

# %%
comp1 = Species("EGFR(L^1,CR1).EGF(R^1)")

# %%
comp2 = Species("EGFR(Y1068=P^1).Grb2(SH2^1)")

# %%
cyjs.init_cyjs()
# Out:
# <script>
# if(window['cytoscape'] === undefined){
#     var paths = {
# 	cytoscape: 'http://cdnjs.cloudflare.com/ajax/libs/cytoscape/2.2.10/cytoscape'
#     };
#
#     console.log('Begin loading all JavaScript libs...');
#     require.config({paths: paths});
#
#     require(['cytoscape'], function(cytoscape){
# 	window['cytoscape'] = cytoscape;
# 	console.log('Finished loading jQuery and Cytoscape.js.');
#
# 	var event = document.createEvent("HTMLEvents");
# 	event.initEvent("load_cytoscape", true, false);
# 	window.dispatchEvent(event);
#     });
# }
# </script>

# %%
cyjs.plot_species(egf)
# Out:
# <!DOCTYPE html>
# <html>
# <head>
# <meta charset=utf-8 />
# <title>Animated BFS</title>
# <style type="text/css">
# body {
#   font: 14px helvetica neue, helvetica, arial, sans-serif;
# }
#
# #cybb1016df-733a-4546-9af9-cf4f03da4761 {
#   height: 500px;
#   width: 500px;
#   position: absolute;
#   left: 0;
#   top: 0;
# }
# </style>
#
# <script>
# (function(){
#
# function render(){
# $('#cybb1016df-733a-4546-9af9-cf4f03da4761').cytoscape({
#   style: cytoscape.stylesheet()
#     .selector('node')
#       .css({
#         'shape': 'data(faveShape)',
#         'background-color': 'data(faveColor)',
#         'content': 'data(name)'
#       })
#     .selector('edge')
#       .css({
#         'target-arrow-shape': 'triangle',
#         'width': 4,
#         'line-color': '#ddd',
#         'target-arrow-color': '#ddd'
#       })
#     .selector('.highlighted')
#       .css({
#         'background-color': '#61bffc',
#         'line-color': '#61bffc',
#         'target-arrow-color': '#61bffc',
#         'transition-property': 'background-color, line-color, target-arrow-color',
#         'transition-duration': '0.5s'
#       }),
#
#   elements: {
#       nodes: [{"data": {"id": "EGF", "name": "EGF"}}, {"data": {"parent": "EGF", "id": "R_EGF", "name": "R"}}],
#
#       edges: []
#     },
#
#   layout: {
#     name: 'breadthfirst',
#     directed: true,
#     roots: '#a',
#     padding: 10
#   },
#
#   ready: function(){
#     window.cy = this;
#
#     var bfs = cy.elements().bfs('#a', function(){}, true);
#
#     var i = 0;
#     var highlightNextEle = function(){
#       bfs.path[i].addClass('highlighted');
#
#       if( i < bfs.path.length ){
#         i++;
#         setTimeout(highlightNextEle, 1000);
#       }
#     };
#
#     // kick off first highlight
#     highlightNextEle();
#   }
# });
# };
#
# var before_render = function(){
#     if(window['cytoscape'] === undefined){
#          console.log("wait!");
# 	 window.addEventListener("load_cytoscape", before_render);
#     }else{
# 	 console.log("begin rendering!");
# 	 render();
#     }
# }
#
# before_render();
#
# })();
# </script>
# </head>
# <body>
#   <div id="cybb1016df-733a-4546-9af9-cf4f03da4761"></div>
#   <!-- When only #uuid div is placed on this page, the height of output-box on ipynb will be 0px. One line below will prevent that. -->
#   <div id="dammy" style="width:700px;height:500px">
# </body>
# </html>

# %%
cyjs.plot_species(egfr)
# Out:
# <!DOCTYPE html>
# <html>
# <head>
# <meta charset=utf-8 />
# <title>Animated BFS</title>
# <style type="text/css">
# body {
#   font: 14px helvetica neue, helvetica, arial, sans-serif;
# }
#
# #cy4c394cdb-a9c1-4bc0-abe8-09b8d8931cea {
#   height: 500px;
#   width: 500px;
#   position: absolute;
#   left: 0;
#   top: 0;
# }
# </style>
#
# <script>
# (function(){
#
# function render(){
# $('#cy4c394cdb-a9c1-4bc0-abe8-09b8d8931cea').cytoscape({
#   style: cytoscape.stylesheet()
#     .selector('node')
#       .css({
#         'shape': 'data(faveShape)',
#         'background-color': 'data(faveColor)',
#         'content': 'data(name)'
#       })
#     .selector('edge')
#       .css({
#         'target-arrow-shape': 'triangle',
#         'width': 4,
#         'line-color': '#ddd',
#         'target-arrow-color': '#ddd'
#       })
#     .selector('.highlighted')
#       .css({
#         'background-color': '#61bffc',
#         'line-color': '#61bffc',
#         'target-arrow-color': '#61bffc',
#         'transition-property': 'background-color, line-color, target-arrow-color',
#         'transition-duration': '0.5s'
#       }),
#
#   elements: {
#       nodes: [{"data": {"id": "EGFR", "name": "EGFR"}}, {"data": {"parent": "EGFR", "id": "CR1_EGFR", "name": "CR1"}}, {"data": {"parent": "EGFR", "id": "L_EGFR", "name": "L"}}, {"data": {"parent": "EGFR", "name": "Y1068", "id": "Y1068=P_EGFR", "faveShape": "rectangle", "faveColor": "#FF0000"}}],
#
#       edges: []
#     },
#
#   layout: {
#     name: 'breadthfirst',
#     directed: true,
#     roots: '#a',
#     padding: 10
#   },
#
#   ready: function(){
#     window.cy = this;
#
#     var bfs = cy.elements().bfs('#a', function(){}, true);
#
#     var i = 0;
#     var highlightNextEle = function(){
#       bfs.path[i].addClass('highlighted');
#
#       if( i < bfs.path.length ){
#         i++;
#         setTimeout(highlightNextEle, 1000);
#       }
#     };
#
#     // kick off first highlight
#     highlightNextEle();
#   }
# });
# };
#
# var before_render = function(){
#     if(window['cytoscape'] === undefined){
#          console.log("wait!");
# 	 window.addEventListener("load_cytoscape", before_render);
#     }else{
# 	 console.log("begin rendering!");
# 	 render();
#     }
# }
#
# before_render();
#
# })();
# </script>
# </head>
# <body>
#   <div id="cy4c394cdb-a9c1-4bc0-abe8-09b8d8931cea"></div>
#   <!-- When only #uuid div is placed on this page, the height of output-box on ipynb will be 0px. One line below will prevent that. -->
#   <div id="dammy" style="width:700px;height:500px">
# </body>
# </html>

# %%
cyjs.plot_species(comp1)
# Out:
# <!DOCTYPE html>
# <html>
# <head>
# <meta charset=utf-8 />
# <title>Animated BFS</title>
# <style type="text/css">
# body {
#   font: 14px helvetica neue, helvetica, arial, sans-serif;
# }
#
# #cy615dde4e-e9c2-409d-83b2-147ce7dcf0b4 {
#   height: 500px;
#   width: 500px;
#   position: absolute;
#   left: 0;
#   top: 0;
# }
# </style>
#
# <script>
# (function(){
#
# function render(){
# $('#cy615dde4e-e9c2-409d-83b2-147ce7dcf0b4').cytoscape({
#   style: cytoscape.stylesheet()
#     .selector('node')
#       .css({
#         'shape': 'data(faveShape)',
#         'background-color': 'data(faveColor)',
#         'content': 'data(name)'
#       })
#     .selector('edge')
#       .css({
#         'target-arrow-shape': 'triangle',
#         'width': 4,
#         'line-color': '#ddd',
#         'target-arrow-color': '#ddd'
#       })
#     .selector('.highlighted')
#       .css({
#         'background-color': '#61bffc',
#         'line-color': '#61bffc',
#         'target-arrow-color': '#61bffc',
#         'transition-property': 'background-color, line-color, target-arrow-color',
#         'transition-duration': '0.5s'
#       }),
#
#   elements: {
#       nodes: [{"data": {"id": "EGFR", "name": "EGFR"}}, {"data": {"parent": "EGFR", "id": "CR1_EGFR", "name": "CR1"}}, {"data": {"parent": "EGFR", "id": "L^1_EGFR", "name": "L"}}, {"data": {"id": "EGF", "name": "EGF"}}, {"data": {"parent": "EGF", "id": "R^1_EGF", "name": "R"}}],
#
#       edges: [{"data": {"target": "R^1_EGF", "id": "^1", "source": "L^1_EGFR"}}]
#     },
#
#   layout: {
#     name: 'breadthfirst',
#     directed: true,
#     roots: '#a',
#     padding: 10
#   },
#
#   ready: function(){
#     window.cy = this;
#
#     var bfs = cy.elements().bfs('#a', function(){}, true);
#
#     var i = 0;
#     var highlightNextEle = function(){
#       bfs.path[i].addClass('highlighted');
#
#       if( i < bfs.path.length ){
#         i++;
#         setTimeout(highlightNextEle, 1000);
#       }
#     };
#
#     // kick off first highlight
#     highlightNextEle();
#   }
# });
# };
#
# var before_render = function(){
#     if(window['cytoscape'] === undefined){
#          console.log("wait!");
# 	 window.addEventListener("load_cytoscape", before_render);
#     }else{
# 	 console.log("begin rendering!");
# 	 render();
#     }
# }
#
# before_render();
#
# })();
# </script>
# </head>
# <body>
#   <div id="cy615dde4e-e9c2-409d-83b2-147ce7dcf0b4"></div>
#   <!-- When only #uuid div is placed on this page, the height of output-box on ipynb will be 0px. One line below will prevent that. -->
#   <div id="dammy" style="width:700px;height:500px">
# </body>
# </html>

# %%
cyjs.plot_species(comp2)
# Out:
# <!DOCTYPE html>
# <html>
# <head>
# <meta charset=utf-8 />
# <title>Animated BFS</title>
# <style type="text/css">
# body {
#   font: 14px helvetica neue, helvetica, arial, sans-serif;
# }
#
# #cyccae675c-9e69-44b5-abf3-16f02aa99b3f {
#   height: 500px;
#   width: 500px;
#   position: absolute;
#   left: 0;
#   top: 0;
# }
# </style>
#
# <script>
# (function(){
#
# function render(){
# $('#cyccae675c-9e69-44b5-abf3-16f02aa99b3f').cytoscape({
#   style: cytoscape.stylesheet()
#     .selector('node')
#       .css({
#         'shape': 'data(faveShape)',
#         'background-color': 'data(faveColor)',
#         'content': 'data(name)'
#       })
#     .selector('edge')
#       .css({
#         'target-arrow-shape': 'triangle',
#         'width': 4,
#         'line-color': '#ddd',
#         'target-arrow-color': '#ddd'
#       })
#     .selector('.highlighted')
#       .css({
#         'background-color': '#61bffc',
#         'line-color': '#61bffc',
#         'target-arrow-color': '#61bffc',
#         'transition-property': 'background-color, line-color, target-arrow-color',
#         'transition-duration': '0.5s'
#       }),
#
#   elements: {
#       nodes: [{"data": {"id": "EGFR", "name": "EGFR"}}, {"data": {"parent": "EGFR", "name": "Y1068", "id": "Y1068=P^1_EGFR", "faveShape": "rectangle", "faveColor": "#FF0000"}}, {"data": {"id": "Grb2", "name": "Grb2"}}, {"data": {"parent": "Grb2", "id": "SH2^1_Grb2", "name": "SH2"}}],
#
#       edges: [{"data": {"target": "SH2^1_Grb2", "id": "^1", "source": "Y1068=P^1_EGFR"}}]
#     },
#
#   layout: {
#     name: 'breadthfirst',
#     directed: true,
#     roots: '#a',
#     padding: 10
#   },
#
#   ready: function(){
#     window.cy = this;
#
#     var bfs = cy.elements().bfs('#a', function(){}, true);
#
#     var i = 0;
#     var highlightNextEle = function(){
#       bfs.path[i].addClass('highlighted');
#
#       if( i < bfs.path.length ){
#         i++;
#         setTimeout(highlightNextEle, 1000);
#       }
#     };
#
#     // kick off first highlight
#     highlightNextEle();
#   }
# });
# };
#
# var before_render = function(){
#     if(window['cytoscape'] === undefined){
#          console.log("wait!");
# 	 window.addEventListener("load_cytoscape", before_render);
#     }else{
# 	 console.log("begin rendering!");
# 	 render();
#     }
# }
#
# before_render();
#
# })();
# </script>
# </head>
# <body>
#   <div id="cyccae675c-9e69-44b5-abf3-16f02aa99b3f"></div>
#   <!-- When only #uuid div is placed on this page, the height of output-box on ipynb will be 0px. One line below will prevent that. -->
#   <div id="dammy" style="width:700px;height:500px">
# </body>
# </html>
