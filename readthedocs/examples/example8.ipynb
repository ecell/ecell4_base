# %% [markdown]
# # MinDE System with Mesoscopic Simulator

# %% [markdown]
# Fange D, Elf J (2006) Noise-Induced Min Phenotypes in E. coli. PLoS Comput Biol 2(6): e80. doi:10.1371/journal.pcbi.0020080

# %%
# %matplotlib inline
from ecell4 import *

# %% [markdown]
# Declaring `Species` and `ReactionRule`s:

# %%
with species_attributes():
    D | DE | {"D": "0.01", "location": "M"}
    D_ADP | D_ATP | E | {"D": "2.5", "location": "C"}

with reaction_rules():
    D_ATP + M > D | 0.0125
    D_ATP + D > D + D | 9e+6 * (1e+15 / N_A)
    D + E > DE | 5.58e+7 * (1e+15 / N_A)
    DE > D_ADP + E | 0.7
    D_ADP > D_ATP | 0.5

m = get_model()

# %% [markdown]
# Make a `World`. The second argument, `0.05`, means its subvolume length:

# %%
w = meso.MesoscopicWorld(Real3(4.6, 1.1, 1.1), 0.05)
w.bind_to(m)

# %% [markdown]
# Make a structures. `Species` `C` is for cytoplasm, and `M` is for membrane:

# %%
rod = Rod(3.5, 0.55, w.edge_lengths() * 0.5)
w.add_structure(Species("C"), rod)
w.add_structure(Species("M"), rod.surface())

# %% [markdown]
# Throw-in molecules:

# %%
w.add_molecules(Species("D_ATP"), 2001)
w.add_molecules(Species("D_ADP"), 2001)
w.add_molecules(Species("E"), 1040)

# %% [markdown]
# Run a simulation for 120 seconds. Two `Observer`s below are for logging. `obs1` logs only the number of molecules, and `obs2` does a whole state of the `World`.

# %%
sim = meso.MesoscopicSimulator(w)
obs1 = FixedIntervalNumberObserver(0.1, [sp.serial() for sp in m.list_species()])
obs2 = FixedIntervalHDF5Observer(1.0, 'minde%03d.h5')

# %%
from ecell4.util.progressbar import progressbar

# %%
duration = 120
progressbar(sim, timeout=1).run(duration, (obs1, obs2))
# Out:
#   [############################]    100.0%  Elapsed:  00:28:11 ETA:  00:00:00

# %% [markdown]
# Visualize the final state of the `World`:

# %%
viz.plot_world(w, radius=0.01, species_list=('D', 'DE'))
# Out:
# <html>
#   <head>
#     <script type="text/javascript">
#      (function(){
#        if(window["THREE"] === undefined || window["d3"] === undefined){
# 	 require.config({
# 	   paths:{
# 	     d3: [
# 	       'https://d3js.org/d3.v3.min',
# 	       'custom/d3.min'
# 	     ],
# 	     THREE: [
# 	       'https://cdnjs.cloudflare.com/ajax/libs/three.js/r66/three.min',
# 	       'custom/three.min'
# 	     ],
#          Elegans: [
#            'https://cdn.rawgit.com/domitry/elegans/15e85b0dafdb6f09181c1ee2f0c47218f6fd698d/release/elegans.min',
# 	       'custom/elegans'
# 	     ]
# 	   },
# 	   shim:{
# 	     THREE: {
# 	       exports: 'THREE'
# 	     },
# 	     Elegans: {
# 	       deps: ['THREE'],
# 	       exports: 'Elegans'
# 	     }
# 	   }
# 	 });
#
# 	 require(["d3", "THREE"], function(d3){
# 	   window["d3"] = d3;
#
# 	   d3.select(document)
# 	     .on("contextmenu", function(){
# 	     d3.selectAll("canvas").style("z-index", 10);
# 	     d3.selectAll(".download_menu").style("z-index", 100);
# 	   });
# 	 });
#        }
#
#        require(["Elegans"], function(){
# 	 console.log("Begin rendering...");
# 	 var model = {"plots": [{"data": {"y": [0.9132241044309922, 0.8661718015209773, 0.5894660424091854, 0.2584163715131581, 0.7964454115834088, 0.8721921821008437, 0.017431956133805215, 0.8167899496038445, 0.10360133174108342, 0.5175877623725683, 0.24573322383221238, 1.0393842445220798, 0.4796792109264061, 0.28031753348186617, 0.13106938331620768, 1.0379383595427498, 0.6440895103150979, 0.4720971543923952, 1.0012643263093195, 0.8199925580411219, 0.3905150061589666, 0.44711646838113667, 0.5013398135080933, 0.6125557117164135, 0.0005706518539227546, 1.010919254354667, 0.3839926846558228, 0.3390898386831396, 0.6026799525949174, 0.9999170954921283, 0.34025582615286115, 0.22559701974969357, 0.2005460189888254, 0.7306932259583846, 0.4739162416895851, 0.51075809848262, 0.9773251228732989, 0.5153125751065091, 0.8458225682028571, 1.090401372651104, 0.6520125486305915, 0.6522499051061459, 0.43248867299407723, 1.084250956773758, 1.037323075637687, 0.31850777182262396, 0.3274706485215575, 0.4225593308452517, 0.28461903529241683, 1.0489639210165478, 0.051851631212048235, 0.40383937533479186, 0.16472158484393734, 0.017284636606927962, 1.0554343722760677, 0.6543614043388516, 0.29936865350464364, 0.2796605714596808, 0.08314703842625022, 0.9301106403465383, 0.6620284534874372, 0.5342971959733405, 0.6931233449140565, 0.27460024635074665, 0.5573591561871581, 0.9445013521588408, 0.9594856829266064, 0.80596877054777, 0.9753300737356767, 0.48631412343820557, 0.880803643888794, 0.0042669027927331625, 0.5358134013717063, 0.40608851725701245, 0.8077408178593033, 0.47165878741070627, 0.7484285544021987, 0.20229963898891584, 0.9052278121118434, 0.8407045579631813, 0.4550252990680747, 0.6573650439968333, 0.07159998111892492, 0.7092589116073214, 0.07056561415083706, 0.3883770365267992, 0.38502945626387375, 1.028073849354405, 0.6103686685557478, 0.21602181512862445, 0.8289956818684004, 0.16779864325653765, 1.066121935634874, 0.15666538419900464, 0.9140560577507131, 0.9324688273249194, 1.0598618812509812, 0.09350611492991448, 1.0383697055629455, 1.0279696271172725, 0.594715316197835, 0.6818566748755984, 0.5044039944303222, 1.0192169522750192, 0.17680163119221107, 0.9466979857767002, 0.22925403589615598, 0.9468582373927348, 0.6978673807228916, 0.23208580524660646, 0.5141068832366728, 0.06987948927562684, 0.6915340515086428, 0.17602843418717387, 0.7013974632602186, 0.9993330615689047, 1.0190846252255141, 1.0277088333852589, 0.09275418587494642, 0.36525113122770564, 0.3001192579278723, 0.4163136048126035, 0.6695115967537277, 0.8246829178417102, 0.10165858367690817, 0.3995975840254687, 0.5830962735111825, 0.6521864753565751, 0.565987589082215, 0.638099856604822, 1.0121724196360447, 0.9776321381330491, 0.4117861023056321, 0.24692296021385118, 0.8496992675936782, 0.5645009558531456, 0.896048860240262, 0.9405558519298212, 0.6415263879811391, 0.7919104972388595, 0.8108655830263161, 0.2992113108746708, 0.4793192918645218, 0.16340804060455413, 0.40857384634437044, 0.4550623707706109, 0.8886682410491631, 0.7439901010831818, 0.20987402341561393, 0.8334289030055516, 0.46085117369657386, 0.5871874833246694, 0.3279203391517513, 0.4089344301261008, 0.8418847877997906, 0.31608165806392213, 0.2591582758817822, 0.30410023274598647, 0.6611528186476789, 0.8342200029175729, 0.37371387965977193, 0.43256273013539615, 0.8281578854192049, 0.9547716815955938, 1.0097461009863764, 0.7010027010226623, 0.30094340656651186, 1.0451092346105726, 0.7782685125828721, 0.9495295373024419, 1.0294376109843142, 0.2587359846453183, 0.848905113793444, 0.6720692839706317, 0.41494763769442217, 0.4310385193792172, 0.44644676489988344, 0.20916439928114416, 0.004655191954225302, 0.02707988169277087, 0.08747210453730077, 0.5106001013424247, 0.4228227505926043, 0.2693755295244046, 0.013334790454246105, 0.7344071925035678, 0.10833246083930136, 0.5762519925250672, 0.0723675383720547, 0.24585791488643735, 0.0931638726266101, 0.28170584024628625, 0.03646184103563428, 0.3854470690363087, 0.8245218081981875, 0.7981 ...

# %% [markdown]
# Plot a time course of the number of molecules:

# %%
viz.plot_number_observer(obs1)

# %%
viz.plot_movie_with_matplotlib(obs2, species_list=('D', 'DE'))
# Out:
# <video controls>
#      <source src="...
